# %% [markdown]
# # Libraries in python

# %% [markdown]
# # Panda

# %% [markdown]
# That’s definitely the synonym of “Python for data analysis”. pandas is an open source, library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
import pandas as pd

# %% [markdown]
# The pd is just abbreviation to make it easier to call the library and can be replace with any other name.

# %% [markdown]
# # Series

# %% [markdown]
# One-dimensional ndarray with axis labels

# %%
pd.Series(data=[1,2,3],index=['a','b','c'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series({'a':1,'b':2})
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# # DataFrame

# %% [markdown]
# Data frames in Python are defined as a two-dimensional labeled data structures with columns of potentially different types.

# %%
pd.DataFrame([[1, 2, 3],[4, 5, 6]],columns=['a','b','c'],index=['f','g'])
# Out:
#    a  b  c
# f  1  2  3
# g  4  5  6

# %% [markdown]
# # CSV file in panda

# %% [markdown]
# You can create dataframes out of various input data formats such as CSV, JSON, Python dictionaries, etc. Once you have the dataframe loaded in Python, you can apply various data analysis and visualization functions to the dataframe and basically turn the dataframe data into valuable information.

# %%
Iris=pd.read_csv('/Users/atousa/Desktop/McMaster/BDA-102/week1-Introduction/Iris.csv',sep=',')

# %% [markdown]
# .info return the general information of the dataset regarding to the number of the rows and columns,the variables, vriables types

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# .head shoews the certains nymber of the rows. Here n is number of the rows to be visible. The first row is the column names and the fisrt column with out header is the row names.

# %%
Iris.head(n=5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# .shape shows the number of columns and rows of the dataFrame

# %%
Iris.shape
# Out:
# (150, 6)

# %% [markdown]
# Here we are selecting specific columns

# %%
Iris_2=Iris[['SepalLengthCm','Species']]

# %%
Iris_2.head(n=5)
# Out:
#    SepalLengthCm      Species
# 0            5.1  Iris-setosa
# 1            4.9  Iris-setosa
# 2            4.7  Iris-setosa
# 3            4.6  Iris-setosa
# 4            5.0  Iris-setosa

# %% [markdown]
# .loc gives the rows of the dataFrame

# %%
Iris_2.loc[[0,1,2]]
# Out:
#    SepalLengthCm      Species
# 0            5.1  Iris-setosa
# 1            4.9  Iris-setosa
# 2            4.7  Iris-setosa

# %% [markdown]
# .iloc gives the index f row which is here the same as row name.

# %%
Iris_2.iloc[[0,1,2]]
# Out:
#    SepalLengthCm      Species
# 0            5.1  Iris-setosa
# 1            4.9  Iris-setosa
# 2            4.7  Iris-setosa

# %% [markdown]
# .ix generate a subset of dataFrame

# %%
Iris_2.ix[0,'Species']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'Iris-setosa'

# %%
y=Iris['Species']

# %%
y.head(n=5)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
y.tail(n=5)
# Out:
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, dtype: object

# %% [markdown]
# Here we category data based on their Species and then take the average of the feature of SepalLengthCm in each category

# %%
Iris_2.groupby('Species')['SepalLengthCm'].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %% [markdown]
# Here we drop a column from our dataFrame

# %%
x=Iris.drop(['Species'],axis=1)

# %%
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is a Python 2D plotting library which produces quality figures in a variety of hardcopy formats and interactive environments. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# The %matplotlib inline activates the inline backend, which renders figures in the notebook as static pngs.This function lets you activate matplotlib interactive support at any point during an IPython session.

# %%
plt.plot(np.array([1,2,3]),np.array([1,2,3]))

# %%
x=np.array([1,2,3])
plt.plot(x,x**2,label='squered')
plt.plot(x,x**3,label='cube')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(np.array([1,2,3]),np.array([1,2,3]),'r')
plt.subplot(1,2,2)
plt.plot(np.array([1,2,3]),np.array([1,2,3]))

# %% [markdown]
# The most familiar way to visualize a bivariate distribution is a scatterplot, where each observation is shown with point at the x and y values. This is analgous to a rug plot on two dimensions.

# %%
x=np.random.rand(100)
y=np.random.rand(100)
plt.scatter(x,y)

# %% [markdown]
# # Plot in panda

# %%
a=Iris_2.groupby('Species')['SepalLengthCm'].mean()

# %%
a
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
a.plot()

# %% [markdown]
# # Seaborn-Statistical plot

# %% [markdown]
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.

# %%
import seaborn as sns

# %% [markdown]
# The most convenient way to take a quick look at a univariate distribution( distribution of single variable) in seaborn is the distplot() function. By default, this will draw a histogram.

# %%
sns.distplot(Iris['SepalWidthCm'])

# %% [markdown]
# Join plot returns the scatter plot of 2 variable as well as distribution of each variable

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=Iris)

# %% [markdown]
# pairplot draw scatterplots for joint relationships and histograms for univariate distributions in diagonal:

# %%
sns.pairplot(Iris.drop(['Id'],axis=1))

# %% [markdown]
# Hue in seaborn plot colors the figures based on a categorical variable such as Species.

# %%
sns.pairplot(Iris.drop(['Id'],axis=1),hue='Species')

# %% [markdown]
# # Categorical plot

# %% [markdown]
# A bar plot represents the average for a numeric variable with the height of each rectangle.

# %%
sns.barplot(x='Species',y='SepalLengthCm',data=Iris)

# %% [markdown]
# Countplot is a barplot where the dependent variable is the number of instances of each instance of the independent variable.

# %%
sns.countplot(x='Species',data=Iris)
